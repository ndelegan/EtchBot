# %%
#6/24/24 Andrea Munoz
"""
  TO-DO: make a menuoption
  consult with team aboout bubbles and percentwhite
"""

# Function to send message to Slack
#TO-DO: install pip install requests on local computer
def send_slack_message(webhook_url, message):
    #Defining JSON
    headers = {'Content-Type': 'application/json'}
    #dictionary payload with message
    payload = {'text': message}

    #POST request to webhook_url
    response = requests.post(webhook_url, headers=headers, data=json.dumps(payload))

    #status_code = 200 means the message was sent successfully
    if response.status_code == 200:
        print('Message sent successfully to Slack!')
    else:
        print(f'Failed to send message to Slack. Error: {response.status_code}, {response.text}')

# Function to execute your script
def run_script(counter, webhook_url):
    string = " C:\\CM400\\photos\\imgCapture"
    string2 = ".bmp"
    filename = f'{string}{counter}{string2}'
    print(filename)
    signatone.save_image(filename)
    print("Executing script...")


def main():
    counter = 0 # counter for image function
    recognition_theter = True #used to start when siglent is on
    bubbles = 0 # used for bubbles detection
    #URL for webhooks app for slack
    webhook_url = 'https://hooks.slack.com/services/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'
    siglent.output_on()
    while recognition_theter:
        time.sleep(10)  # Sleep for 10 seconds
        counter += 1
        run_script(counter, webhook_url)
        #we analuyze the recent image using the counter used in the image function
        filepath = f"C:\\CM400\\photos\\imgCapture{counter}.bmp"
        image = cv2.imread(filepath)
        #if bubbles are covering then send message on Slack
        if bubbles is not None:
            message = f"Bubbles obstruction"
            send_slack_message(webhook_url, message)
        if image is not None:
            # Assuming you have a condition to check percentage white
            percentagewhite = 93
            if percentagewhite >= 93:
                # Stop siglent (assuming siglent is defined somewhere)
                siglent.output_off()
                recognition_theter = False
                break
        else:
            print("Failed to load image")

        # Move the probes to next square logic can be added here

        # If CV doesn't recognize square, move up or down logic can be added here
    recognition_theter = True


if __name__ == "__main__":
    main()

# %%
"""

    Automation program for the etching of diamond membranes from a 9x9 sample grid.

    Authors: UIC Chicago Tech Circle Team (Andrea Munoz, Fernanda Villalpando, Claudia Jimenez, Lisette Ruano, Aima , Lisset Rico)
    Collaborator(s): Argonne National Laboratory (Nazar Delegan, Clayton Devault)
    Date Created: 06/20/2024

    Current Version:
    To-Do:

"""

import time
import siglent_driver as Sigl
import signatone_driver as Sign
import cv2
import requests
import json

def square_detect():
  pass

def bubble_detect():
  pass

def area_check():
  pass

# Function to send message to Slack
#TO-DO: install pip install requests on local computer
def send_slack_message(webhook_url, message):
  #Defining JSON
  headers = {'Content-Type': 'application/json'}
  #dictionary payload with message
  payload = {'text': message}

  #POST request to webhook_url
  response = requests.post(webhook_url, headers=headers, data=json.dumps(payload))

  #status_code = 200 means the message was sent successfully
  if response.status_code == 200:
    print('Message sent successfully to Slack!')
  else:
    print(f'Failed to send message to Slack. Error: {response.status_code}, {response.text}')


# Function to execute your script
def run_script(counter, webhook_url):
  string = " C:\\CM400\\photos\\imgCapture"
  string2 = ".bmp"
  filename = f'{string}{counter}{string2}'
  print(filename)
  signatone.save_image(filename)
  print("Executing script...")



# Set up device
siglent = Sigl.Siglent()
signatone = Sign.Signatone()


# Timer for image capturing (resource found here)
# Time difference using while True
# Import threading, Import time
# SAVE IMAGE filename


# Set up environment for CV
# Convert to grayscale and blur image:
# img_gray  = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)
# img_blur = cv2.blur(img_gray, (10,10))
# Recognize membrane
# square/rectangle detection


# Move probes before etching

# Using MOVEABS,MOVEREL,CAPUP,CAPDOWN commands
    #
# Place probes on street
# Move probes a couple of microns up/down to avoid scratching the membrane
# Take the stage height(chuck) GETZCHUCK, then take the probe height GETCAP. Subtract the probe height from stage height.
# If the probe height + offset is less than stage height + offset then we can keep lowering
# If the probe height + offset is equal to or greater than stage height + offset then definitely touching sample
# Example of potential code:
# Start etching
# Run Siglent driver


# CV: Identify bubbles
# Keep track of how many bubbles are present, determine when etching should stop, clear bubbles, then continue etching
# Use Hough Circle function to identify bubbles


# CV: Keep track of area of tether left
# perhaps average with the other already done

# Stop etching when threshold reached
# Move probes up & keep track of the number we use.


# Move chuck to get next square
# Detect when a new square appears as a guideline
# Use the same number that we use to move the probes up, to lower them back in place

signatone.set_dev(chuck)

# 2 cases: next square is still in the row OR end of the row
# perhaps use a counter if that doesn't take too much more space

if count < row_len:
  # move chuck to the next row

while not square and not middle:
  signatone.move_x()

signatone.set_dev(P1)
# move probe left or right
signatone.move_z(chuck_offset)
# perhaps also moving it side to side if not hitting the exact corner, while loop
signatone.set_dev(P2)
# move probe left or right
signatone.move_z(chuck_offset)
# perhaps also moving it side to side if not hitting the exact corner, while loop
# Out:
#   File "<ipython-input-1-6d8e9ff66444>", line 89
#     while not square and not middle:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 86
